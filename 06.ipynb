# %%
from PIL import Image
from imgtools import *
from IPython.display import display

img_dir = 'C:/Users/ADMIN/tgmt/image/'
img1 = load_image(img_dir+'/zhezhi.jpg')
img1 = img1.resize((250,250))
#display(img1)

gray_img=img1.convert("L")
#display(gray_img)

red_band, green_band, blue_band = img1.split()
display(red_band)
display(green_band)
display(blue_band)

merge_img=Image.merge("RGB",(red_band, green_band, blue_band))
display(merge_img)
# Out:
# <PIL.Image.Image image mode=L size=250x250>
# <PIL.Image.Image image mode=L size=250x250>
# <PIL.Image.Image image mode=L size=250x250>
# <PIL.Image.Image image mode=RGB size=250x250>
