# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

_Path = 'C:/Users/ADMIN/tgmt/image/zhezhi.jpg'
Rim = Image.open(_Path)
Rim_GRAY = Rim.convert('L')
Rim_AR_GRAY= np.array(Rim_GRAY)

#Shape(Column,Row)
print(Rim_AR.shape)

#Convert to Gray
print(im_array_2.shape)
print(im_array_2.dtype)

#Change the type to our needs
inverted_image = 255 - Rim_AR_GRAY  # Invert pictures by taking 255- pixel's vlue
squared_image = Rim_AR_GRAY ** 2 #Square the pixel's value
clamped_image = np.clip(Rim_AR_GRAY, 100, 200) #Limit the pixel's value within 100 and 200

# Show origin pictures and Changed pictures with "white space"
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
fig.subplots_adjust(wspace=0.2, hspace=0.2)

axs[0, 0].imshow(Rim_AR_GRAY, cmap="gray")
axs[0, 0].set_title('Hình ảnh gốc')

axs[0, 1].imshow(inverted_image, cmap="gray")
axs[0, 1].set_title('Hình ảnh đã biến đổi = Inverted')

axs[1, 0].imshow(squared_image, cmap="gray")
axs[1, 0].set_title('Hình ảnh đã biến đổi = Squared')

axs[1, 1].imshow(clamped_image, cmap="gray")
axs[1, 1].set_title('Hình ảnh đã biến đổi = Limit')
# Out:
# (1080, 1920, 3)
# (1080, 1920)
# float32
# Text(0.5, 1.0, 'Hình ảnh đã biến đổi = Limit')
