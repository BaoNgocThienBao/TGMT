# %%
from PIL import Image
from imgtools import *
from IPython.display import display

img_dir = 'C:/Users/ADMIN/tgmt/image/'
img1 = load_image(img_dir+'/zhezhi.jpg')
new_resize=(500,500)
New_res = img1.resize(new_resize)
#display(New_res)

rotated_90=New_res.rotate(90)
#display(rotated_90)

rotated_90_90 = rotated_90.rotate(90)
#display(rotated_90_90)

transP_img = New_res.transpose(Image.Transpose.ROTATE_90)
display(transP_img)

transP_img = transP_img.transpose(Image.Transpose.ROTATE_90)
display(transP_img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>
# <PIL.Image.Image image mode=RGB size=500x500>
