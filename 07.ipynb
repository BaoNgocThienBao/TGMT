# %%
#!pip install matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image

img_dir = 'C:/Users/ADMIN/tgmt/image/'
img1 = load_image(img_dir+'/zhezhi.jpg')
transP_img = img1.transpose(Image.Transpose.ROTATE_180)
#plt.imshow(img1) #show_xyz_of_pics

x=[1,3,5,7,9]
y=[0,4,6,6,10]
plt.plot(x,y,color="red")
plt.title("Example about xyz stuffs")
plt.axis('off')
plt.show()

#Table_stuffs
plt.imshow(transP_img)
x=[100,567,1078,1420]
y=[190,298,333,960]
plt.background=(img1)
plt.gca().invert_yaxis()
plt.plot(x,y,'yo--')
plt.title("Table example")
plt.show()
