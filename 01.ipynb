# %%
# Ctrl + Enter = run

# %%
from PIL import Image
dir = 'C:/Users/ADMIN/tgmt/image'
image_path= dir +'/zhezhi.jpg'
print(image_path)
imguse=Image.open(image_path)
display(imguse)
print('Định dạng ảnh:', imguse.format)
print('Kích thước hình ảnh',imguse.size)
new_jpg_img = dir+'/new_zhezhi.jpg'
new_png_img = dir+'/new_zhezhi.png'
imguse.save(new_jpg_img)
imguse.save(new_png_img)
imguse.close()
# Out:
# C:/Users/ADMIN/tgmt/image/zhezhi.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080>
# Định dạng ảnh: JPEG
# Kích thước hình ảnh (1920, 1080)
